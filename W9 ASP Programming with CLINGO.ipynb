# %%
from PW_explorer.run_clingo import run_clingo
from PW_explorer.load_worlds import load_worlds
from PW_explorer.pwe_nb_helper import ASPRules
# help to read magic function %clingo and magic %%clingo
# %load_ext PWE_NB_Extension

# %% [markdown]
# # 0. Warm Up

# %%
# %%clingo --run --donot-display_input
#
# % facts
# t(austin,88).
# t(dallas,95).
# t(houston,90).
# t(san_antonio,85).
#
# % rules
# warm(C) :- t(C, T1), t(austin, T2), T1>T2.
#
# #show warm/1.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %% [markdown]
# # 1.  Arithmic
# - The only numbers that clingo knows about are integers

# %%
# %%clingo --run --donot-display_input
# p(N,N*N+N+41) :- N=0..10.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# p(N,N*N+N+41) :- N+1=1..11.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %% [markdown]
# ### What happen in Head

# %%
# %%clingo --run --donot-display_input
# p(1..3).
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# square(1..3, 1..3).
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# p(1..2,1..4).
# p(1..4,1..2).
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %% [markdown]
# ### Constaint

# %%
# %%clingo --run --donot-display_input
# #const n=10.
# #const a=1.
# #const b=1.
# #const c=41.
# p(N,a*N*N+b*N+c) :- N=0..n.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
#
# % facts
# t(austin,88).
# t(dallas,95).
# t(houston,90).
# t(san_antonio,85).
#
# % rules
# warm(C) :- t(C, T1), t(c, T2), T1>T2.
# #const c = austin.
# #show warm/1.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %% [markdown]
# # 3. Definitions
# - Many ASP rules can be thought of as definitions.
# - Example:  Rule `child(X,Y) :- parent(Y,X).` defines child/2 in terms of parent/2.

# %%
# %%clingo --run --donot-display_input
# % What is the Pime Numbers with 100
# composite(N) :- N=1..n, I=2..N-1, N\I=0.
#     prime(N) :- N=2..n, not composite(N).
#
# #const n = 100.
# #show prime/1.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# % Example about family ancestor realtionship
#
# % Rules
# parent(X,Y) :- father(X,Y).
# parent(X,Y) :- mother(X,Y).
# ancestor(X,Y) :- parent(X,Y).
# ancestor(X,Y) :- ancestor(X,Z), ancestor(Z,Y).
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# % factorials n!
# fac(1 ,1).
# fac(N+1,F*(N+1)) :- fac(N,F), N<n.
# #const n = 5.
# #show fac/2.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %% [markdown]
# # 4. Choice Rules and Constraints

# %% [markdown]
# ### in Head
# - Use {} and ;

# %%
# %%clingo --run --donot-display_input
#
# {p(a);q(b)}.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %% [markdown]
# Number of Choices <br>
# SUM = C(3,0) + C(3,1) + C(3,2) + C(3,3) = 1+3+3+1 = 8 <br>
# SUM = 2^3<br>

# %%
# %%clingo --run --donot-display_input
# {p(1..3)}.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# % Choices: 8*8
# {p(1..3)}.
# {q(1..3)}.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# % Choices: C(3,0)*C(3,0) + C(3,1)*C(3,1) + ...
# {p(1..3,1..3)}.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# % At least choose one
# % C(6,1..6) = 6 2^6 -1 =63
# 1 {p(1..6)}.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# % At least choose 3 elements, at most choose 3 elements
# 3 {p(1..6)} 3.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# % 2^n choices
# 1 {p(X);q(X)} 1 :- X=1..n.
# #const n = 3.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# {p(a);q(b)}.
#
# % CONSTRAINTS
# :- p(a), q(b).
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %% [markdown]
# # 5.0 Combinatorial Search

# %%
# %%clingo --run --donot-display_input
# % Seat Arrangement
#
# % For each chair, there is exactly one guest
# 1{at(1..n, C)} 1 :- C = 1..n.
#
# % No guest sit on two chairs.
# C1 = C2 :- at(G,C1), at(G,C2).
#
# % Two chairs are next to each other
# adj(X,Y) : X=1..n, Y=1..n, |X-Y| = 1.
# adj(1, n; n, 1).
#
# :- like(G1,G2), at(G1,C1), at(G2,C2), not adj(C1,C2).
# :- dislike(G1,G2), at(G1,C1), at(G2,C2), adj(C1,C2).
#
# #show at/2.
#
# #const n = 6.
# like(1,2; 3,4).
# dislke(2,3; 1,3).
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

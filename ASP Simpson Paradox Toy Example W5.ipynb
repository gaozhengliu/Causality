# %% [markdown]
# ## Week 5 ASP Practice
# #### 2020-6-22 ~ 2020-6-28
# ASP Toy example based on clingo guide.pdf

# %%
from PW_explorer.run_clingo import run_clingo
from PW_explorer.load_worlds import load_worlds
from PW_explorer.pwe_nb_helper import ASPRules
from copy import deepcopy

# %%
# help to read magic function %clingo and magic %%clingo
# %load_ext PWE_NB_Extension

# %% [markdown]
# ### Example
# - if Tux is a penguin, can Tux fly?
# - if Tweety is a chicken, can Tweety fly?
#
# #### Negation is used in this example.
# It will generate two possible worlds
# - one world tux can fly
# - one world tux can not fly

# %%
# %%clingo --run --donot-display_input
# % facts
# bird(tux). penguin(tux).
# bird(tweety). chicken(tweety).
# % rules
# flies(X) :- bird(X), not -flies(X).
# -flies(X) :- bird(X), not flies(X).
# -flies(X) :- penguin(X).
# % constrain
# :- flies(tux), -flies(tux).
# :- flies(tweety), -flies(tweety).
# #show flies/1.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %% [markdown]
# ### Example Course Selection
#
# - Why show doesn not work here?
# - How sum function works?

# %%
# %%clingo --run --donot-display_input
# % Facts
# % course (course number [1:8]; the subject are: 1 theoretical info, 2 practical info, 3 technical info, 4 applied info; contact hour)
# course(1,1,5).course(1,2,5).
# course(2,1,4).course(2,2,4).
# course(3,1,6).course(3,3,6).
# course(4,1,3).course(4,3,3).course(4,4,3).
# course(5,1,4).course(5,4,4).
# course(6,2,2). course(6,3,2).
# course(7,2,4). course(7,3,4). course(7,4,4).
# course(8,3,5). course(8,4,5).
# % Constraint
# % regards three to six courses should be enrolled, 210
# 3 { enroll(C): course(C,_,_) } 6.
# %3 { enroll(1), enroll(2), enroll(3), enroll(4), enroll(5), enroll(6), enroll(7), enroll(8) } 6.
#
# % regards to subject of the courses
# % [] interate enroll(C) = 1
# %:- [ enroll(C) : course(C,_,_) ] 10.
# %:- 2 [ not enroll(C) : course(C,2,_) ].
# %:- 6 [ enroll(C) : course(C,3,_), enroll(C) : course(C,4,_) ].
#
# % Rules that project course/3 to hour/2
# hours(C,H) :- course(C,S,H).
# max_hours(20).
# %:- not M-2 [ enroll(C): hours(C,H) = H] M, max_hours(M).
# %:- #min [ enroll(C) : hours(C,H) = H ] 2.
# %:- 6 #max [ enroll(C) : hours(C,H) = H ].
# :- enroll(C), hours(C,H), H <= 2.
# :- enroll(C), hours(C,H), H >= 6.
#
# courses(N) :- N = #count { enroll(C) : course(C,_,_) }.
# % Seems all sum function does not work in this version
# %hours(N) :- N = #sum [ enroll(C) : hours(C,H) = H ].
#
#
# %# show enroll/1.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %% [markdown]
# ### Example Hotel

# %%
# %%clingo --run --donot-display_input
# 1 { hotel(1..5) } 1.
# star(1,5). star(2,4). star(3,3). star(4,3). star(5,2).
# cost(1,170). cost(2,140). cost(3,90). cost(4,75). cost(5,60).
# main_street(4).
# noisy :- hotel(X), main_street(X).
# hotel_cost(X,Z) :- hotel(X), star(X, Y),cost(Y, Z).
# %#maximize [ hotel(X) : star(X,Y) = Y @ 1 ].
# %#minimize [ hotel(X) : cost(X,Y) : star(X,Z) = Y/Z @ 2 ].
# %#minimize { noisy @ 3 }.
# #show hotel_cost/2.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# q(1;2).
# { p(1..3) }.
#  :- 1 {  p(X) : q(X) }.
# %#compute { not p(X) : X=4..5 }.
#  %:- 1 { p(X) : X=4..5 }.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# q(1;2).
# { p(1..3) }.
# %#compute 0 { p(X) : q(X) }.
#  :- 1 { not p(X) : q(X) }.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# q(1;2).
# { p(1..3) }.
# :- 1 { not p(X) : q(X) }.
# %#compute { not p(X) : X=3..5 }.
# :- 1 { p(X) : X=3..5 }.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %%
# %%clingo --run --donot-display_input
# % Nodes
# node(1..6).
# % (Directed) Edges
# edge(1,2;3;4). edge(2,4;5;6). edge(3,1;4;5).
# edge(4,1;2). edge(5,3;4;6). edge(6,2;3;5).
#  % Default
# #const n = 3.
#  % Generate
#  1 { color(X,1..n) } 1 :- node(X).
#  % Test
#  :- edge(X,Y), color(X,C), color(Y,C).
#
# %1 { color(1,1), color(1,2), color(1,3) } 1.
# Out:
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# ANTLR runtime and generated code versions disagree: 4.8!=4.7.1
# Output:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# ...

# %% [markdown]
# ## Towers of Hanoi
# #### Question
# -- why predicate move was overload. move/2, move/3
# in line 9 and 12 move(D,P,T) represent move disk to pedigram in Th move, however in line 12 and 15, also have a move (D,T), lack of information about the pendigram that the disk moves towards.
#
# -- blocked/3 is used to prohibit to put a larger disk on top of a smalller one.
# -- Two blocked/3

# %%
# %%clingo --run  --donot-display_input
# peg(a;b;c).
# disk(1..4).
# init_on(1..4,a).
# goal_on(1..4,c).
# moves(15).
# %Generate
# 1{ move(D,P,T): disk(D): peg(P) }1 :- moves(M), T = 1..M.
# %Define
# move(D,T) :- move(D,_,T).
# on(D,P,0) :- init_on(D,P).
# on(D,P,T) :- move(D,P,T).
# on(D,P,T+1):- on(D,P,T), not move(D,T+1), not moves(T).
# blocked(D-1,P,T+1) :- on(D, P, T), disk(D), not moves(T).
# blcoked(D-1,P,T)   :- blocked(D,P,T), disk(D).
# %Test
# :- move(D,P,T), blocked(D-1,P,T).
# :- move(D,T), on(D,P,T-1), blocked(D,P,T).
# :- goal_on(D,P), not on(D,P,M), moves(M).
# :- not 1{on(D,P,T):peg(P)}1, disk(D), moves(M),T=1..M.
# #hide.
# #show move/3.
# Out:
# Input:
#         <style>
#         .highlight .hll { background-color: #ffffcc }
# .highlight  { background: #f8f8f8; }
# .highlight .c { color: #408080; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #408080; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #408080; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #BC7A00 } /* Comment.Preproc */
# .highlight .cpf { color: #408080; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #408080; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #408080; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #FF0000 } /* Generic.Error */
# ...
